# %% [markdown]
# Additional Graphs With MatplotLib

# %% [markdown]
# Scatter Plot
# Scatter (plot) graphs will plot one point per observation, we can use these to graph independent variables to see if there is a correlation. Python will require two sets of variables for a scatter graph, one for the x-axis and another for the corresponding y axis. These sets will need to be of the same length and work best as lists, array, or array-like data types. We can call ‘pyplot’ to plot a scatter with the pyplot.scatter(x,y) call

# %% [markdown]
# Example:1
# //SABIN CHAULAGAIN

# %%
#2358554
#SABIN CHAULAGAIN
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7,8,9]
y=[3,4,5,6,7,8,9,10,11]
plt.scatter(x,y,color="red",marker="^")
plt.show()

# %% [markdown]
# Example 2

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7,8,9]
y=[3,4,5,6,7,1,9,2,5]
plt.scatter(x,y,color="red",marker="^")
x1=[1,5,6,8,12]
y1=[2,6,7,11,13]
plt.scatter(x1,y1,color="blue",marker="s")
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.title("Scatter plot")
plt.show()

# %% [markdown]
# Task:1
# Create a scatter graph of 10 random x and y values between 0 and 50. Label the axis to show
# x – Time taken in seconds
# y – Distance reached
# Title - “Buzzer Game Results”
# One you have a working program, add the following code to your program; colors=[”red”,”green”,”blue”,”yellow”,”pink”,”orange”,”purple”,”brown”,”cyan”,”magenta”] and add to your scatter() call the ‘c=colors’ argument like so; plt.scatter(x, y, c=colors) What happens?

# %%
import matplotlib.pyplot as plt
import numpy as np
a=10
b=np.random.uniform(0,50,a)
c=np.random.uniform(0,50,a)
plt.scatter(b,c,marker="s")
plt.xlabel("time taken in Second")
plt.ylabel("Distance reached")
plt.title("TITLE-BUZZER GAME RESULTS")
plt.show()

# %% [markdown]
# Pie- Chart

# %% [markdown]
# Example:3

# %%
import matplotlib.pyplot as plt
y=[100,205,307,409,200]
groups=["Pulsar","Duke","Enfield","Honda","Hero"]
plt.pie(y,labels=groups)
plt.show()

# %% [markdown]
# Task:2

# %%
import matplotlib.pyplot as plt
years=[2017,2018,2019,2020,2021,2022]
population_of_bear=[8,54,93,116,137,184]
population_of_dolphins=[150,77,32,11,6,1]
population_of_whales=[80,54,100,76,93,72]
plt.pie(population_of_bear,labels=years)
plt.title("BEAR POPULATION")
plt.show()
plt.pie(population_of_dolphins,labels=years)
plt.title("DOLPHINS POPULATIONS")
plt.show()
plt.pie(population_of_whales,labels=years)
plt.title("WHALES POPULATIONS")
plt.show()

# %% [markdown]
# Task:3

# %%
import matplotlib.pyplot as plt
a=[45,30,15,30,30]
data=["Mango","Orange","Plum","Pineapple","Melon"]
plt.pie(a,labels=data)
plt.title("FAVROURITE FRUIT OF STUDENTS")
plt.show()

# %% [markdown]
# Bar Plot

# %% [markdown]
# Example:4

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
data = [23, 45, 56, 78, 213]
plt.bar(x, data,width=0.5,color="maroon")
plt.title("A bar plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %% [markdown]
# Task:4

# %%
import matplotlib.pyplot as plt
a=["red","silver","blue","white","green"]
b=[123,230,78,193,12]
plt.bar(a,b, width =0.3)
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
a=["red","silver","blue","white","green"]
b=[123,230,78,193,12]
plt.barh(a,b)
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
a=["red","silver","blue","white","green"]
b=[123,230,78,193,12]
bar_colors=["red","silver","green","blue","yellow"]
plt.bar(a,b, color=bar_colors)
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.show()

# %% [markdown]
# PIE CHART OF CAR DATA ABOVE ADD TITLE

# %%
a=["red","silver","blue","white","green"]
b=[123,230,78,193,12]
plt.pie(b,labels=a)
plt.title("DIVISION CAR COLORS")
plt.show()

# %%
import matplotlib.pyplot as plt
x=["red","silver","blue","white","green"]
y=[123,230,78,193,12]
myexplode=[0.3,0,0,0,0]
plt.pie(y,labels=x,explode=myexplode,shadow= True)
plt.title("Division Car Colors")


plt.show()

# %% [markdown]
# HistogrAM

# %%
from matplotlib import pyplot as plt
# Creating a sample dataset
array = [23, 56, 87, 87, 98,
12, 76, 98, 34, 87,
67, 23, 87, 56, 34, 26, 85, 47, 35, 86,
76, 45, 86, 34, 37, 99,23,33,44,56,77,33,
34,56,88,44,55]

plt.hist(array , bins = 5)
plt.show()

# %% [markdown]
# TASK:5

# %% [markdown]
# Histogram:
# Historam is graphical representation of dataset that shows the frequency occurance of values with different interavals or bins. Histogram helps to
# visualiza different data and makes easy to understand easily for us.
# Histogram helps to understand set of data so fast and makes easy for study
